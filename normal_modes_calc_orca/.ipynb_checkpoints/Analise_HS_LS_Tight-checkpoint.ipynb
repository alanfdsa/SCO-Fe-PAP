# %% [markdown]
# # Bibliotecas e dados

# %%
# %matplotlib qt
import pandas as pd
import re
import numpy as np
from io import StringIO   # <-- use isto
import matplotlib.pyplot as plt
import mplcursors
#%matplotlib widget # Isso anula usar o matplotlib qt
#%matplotlib notebook

# %% [markdown]
# # Modos normais com os átomos indexados

# %%
hs = pd.read_csv("Oct_Contri_hs.csv")
ls = pd.read_csv("Oct_Contri_ls.csv")

# %%
def renomear_index_por_atom(df, lista_atomica):
    """
    df: DataFrame final já criado (159 linhas)
    lista_atomica: lista de strings com linhas contendo símbolo, massa e coordenadas
    """
    # Extrair apenas o símbolo atômico de cada linha
    simbolos = [linha.split()[0] for linha in lista_atomica]

    novo_index = []
    contadores = {}  # exemplo: {"C":1, "H":1, "O":1}

    for simbolo in simbolos:
        if simbolo not in contadores:
            contadores[simbolo] = 1

        nome = f"{simbolo}{contadores[simbolo]}"

        # Cada átomo corresponde a 3 linhas do DataFrame
        novo_index.extend([nome, nome, nome])

        contadores[simbolo] += 1

    # Aplicar ao DataFrame
    df.index = novo_index
    return df

# %%
lista_atomica = [
    "C     12.01100     -5.520264845720    -1.115707479413     0.897605357711",
    "C     12.01100      5.520452518574    -1.115723577676    -0.897303843581",
    "C     12.01100     -4.717428065189    -2.832744402920    -1.052293345657",
    "C     12.01100      4.717889260456    -2.832871384362     1.052539744557",
    "C     12.01100     -6.606891583710    -4.394353536396    -2.145371212533",
    "C     12.01100      6.607390344081    -4.394770037602     2.145057663476",
    "H      1.00800     -6.034676638152    -5.702671048362    -3.610513207819",
    "H      1.00800      6.035355292474    -5.703243699406     3.610128208214",
    "C     12.01100     -9.066360064720    -4.254075940367    -1.367474199670",
    "C     12.01100      9.066728222324    -4.254628795559     1.366661179528",
    "H      1.00800    -10.511265866955    -5.441454535473    -2.193507432040",
    "H      1.00800     10.511683451023    -5.442288278089     2.192214608511",
    "C     12.01100     -9.770578178244    -2.550150813499     0.537008619724",
    "C     12.01100      9.770715542304    -2.550563288206    -0.537744580628",
    "C     12.01100     -8.020310169408    -0.994075397066     1.671451991949",
    "C     12.01100      8.020340638195    -0.994159763824    -1.671623622263",
    "N     14.00700    -12.378556223629    -2.409089787803     1.327755332438",
    "N     14.00700     12.378519201596    -2.409668247301    -1.329083667815",
    "O     15.99900     -2.416219571234    -2.903288706253    -1.747879105684",
    "O     15.99900      2.416744722791    -2.903297471670     1.748496268000",
    "O     15.99900    -13.888079551984    -3.808782207744     0.304531482779",
    "O     15.99900     13.888086558489    -3.809858819272    -0.306655649681",
    "O     15.99900    -12.928247729108    -0.893379703175     2.972383430461",
    "O     15.99900     12.927953998234    -0.893763939771    -2.973651371779",
    "N     14.00700     -3.564693824940     0.330596326795     1.821477061978",
    "N     14.00700      3.564735878326     0.330650146953    -1.820781402117",
    "H      1.00800     -8.649557134583     0.282766099379     3.140249066382",
    "H      1.00800      8.649412269810     0.282821974285    -3.140385031032",
    "C     12.01100     -3.655291153411     2.031063880783     3.536851991090",
    "C     12.01100      3.655056986834     2.030838091497    -3.536441828175",
    "H      1.00800     -5.377071945919     2.549964151628     4.541848489297",
    "C     12.01100     -1.310384408628     3.291486455883     4.191970491532",
    "C     12.01100      1.310046939264     3.291108840358    -4.191443794614",
    "H      1.00800      5.376641385352     2.549464552762    -4.541919460723",
    "N     14.00700      0.741387328905     2.577206192449     2.876254138590",
    "C     12.01100     -1.181804924987     5.094014086095     6.099820375343",
    "C     12.01100      1.181227147302     5.093277810341    -6.099625154786",
    "N     14.00700     -0.741599888669     2.576856952799    -2.875508194828",
    "C     12.01100      2.955085757498     3.593295877611     3.458276208785",
    "H      1.00800     -2.881312278661     5.626521498741     7.109401298976",
    "C     12.01100      1.133402062841     6.155165171408     6.683444521954",
    "H      1.00800      2.880649251831     5.625718623776    -7.109394845466",
    "C     12.01100     -1.134093225637     6.154099585433    -6.683384268274",
    "C     12.01100     -2.955402360777     3.592657946625    -3.457669967266",
    "H      1.00800      4.565823766006     2.942241245285     2.371070162337",
    "C     12.01100      3.249950073085     5.383762691732     5.348576630598",
    "H      1.00800      1.287843102082     7.556621529536     8.167726618197",
    "C     12.01100     -3.250503942796     5.382767012137    -5.348272220948",
    "H      1.00800     -1.288716667155     7.555250245205    -8.167932773460",
    "H      1.00800     -4.566072050899     2.941572288416    -2.370400223201",
    "H      1.00800      5.104212185344     6.145690387923     5.751937690401",
    "H      1.00800     -5.104864181243     6.144415297879    -5.751727712650",
    "Fe    55.85000      0.000239285754    -0.441112578978     0.000655619575"
]

# %%
arquivo = "ls_tight/vib_mode.txt"

with open(arquivo, "r") as f:
    linhas = f.readlines()

# --------------------
# 1) Parte inicial (159 linhas)
# --------------------

linhas_159 = linhas[:159]

header = re.split(r"\s+", linhas[0].strip())
header = [h for h in header if h != ""]

df = pd.read_csv(
    StringIO("".join(linhas_159)),
    delim_whitespace=True,
    names=header,
    skiprows=1
)

# --------------------
# 2) Blocos seguintes
# --------------------

blocos = []
i = 159

num_regex = r"^\s*\d+(\s+\d+)*\s*$"

while i < len(linhas):

    # Linha com números das colunas
    col_header_line = linhas[i].strip()
    novas_cols = re.split(r"\s+", col_header_line)
    novas_cols = [c for c in novas_cols if c != ""]
    i += 1

    bloco_linhas = []

    # Acumular linhas do bloco
    while i < len(linhas) and not re.match(num_regex, linhas[i]):
        bloco_linhas.append(linhas[i])
        i += 1

    # Se não houver linhas, pula
    if len(bloco_linhas) == 0:
        continue

    # ----------------------------
    # Detectar número real de colunas no bloco
    # ----------------------------
    primeira_linha = bloco_linhas[0].strip()
    ncols = len(re.split(r"\s+", primeira_linha))

    # criar nomes para todas as colunas
    # primeira é índice, outras são novas_cols (até onde existirem)
    nomes = ["idx"] + novas_cols + [f"extra_{k}" for k in range(len(novas_cols)+1, ncols)]

    df_bloco = pd.read_csv(
        StringIO("".join(bloco_linhas)),
        delim_whitespace=True,
        names=nomes
    )

    df_bloco = df_bloco.drop(columns=["idx"])
    blocos.append(df_bloco)

# --------------------
# 3) Concatenar
# --------------------

for b in blocos:
    df = pd.concat([df, b], axis=1)
# Out:
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\1016384295.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(

# %%
df = renomear_index_por_atom(df, lista_atomica)
normal_modes_ls = df

# %%
arquivo = "hs_tight/vib_mode.txt"

with open(arquivo, "r") as f:
    linhas = f.readlines()

# --------------------
# 1) Parte inicial (159 linhas)
# --------------------

linhas_159 = linhas[:159]

header = re.split(r"\s+", linhas[0].strip())
header = [h for h in header if h != ""]

df = pd.read_csv(
    StringIO("".join(linhas_159)),
    delim_whitespace=True,
    names=header,
    skiprows=1
)

# --------------------
# 2) Blocos seguintes
# --------------------

blocos = []
i = 159

num_regex = r"^\s*\d+(\s+\d+)*\s*$"

while i < len(linhas):

    # Linha com números das colunas
    col_header_line = linhas[i].strip()
    novas_cols = re.split(r"\s+", col_header_line)
    novas_cols = [c for c in novas_cols if c != ""]
    i += 1

    bloco_linhas = []

    # Acumular linhas do bloco
    while i < len(linhas) and not re.match(num_regex, linhas[i]):
        bloco_linhas.append(linhas[i])
        i += 1

    # Se não houver linhas, pula
    if len(bloco_linhas) == 0:
        continue

    # ----------------------------
    # Detectar número real de colunas no bloco
    # ----------------------------
    primeira_linha = bloco_linhas[0].strip()
    ncols = len(re.split(r"\s+", primeira_linha))

    # criar nomes para todas as colunas
    # primeira é índice, outras são novas_cols (até onde existirem)
    nomes = ["idx"] + novas_cols + [f"extra_{k}" for k in range(len(novas_cols)+1, ncols)]

    df_bloco = pd.read_csv(
        StringIO("".join(bloco_linhas)),
        delim_whitespace=True,
        names=nomes
    )

    df_bloco = df_bloco.drop(columns=["idx"])
    blocos.append(df_bloco)

# --------------------
# 3) Concatenar
# --------------------

for b in blocos:
    df = pd.concat([df, b], axis=1)
# Out:
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(
# C:\Users\alanf\AppData\Local\Temp\ipykernel_26096\2067696187.py:60: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_bloco = pd.read_csv(

# %%
df = renomear_index_por_atom(df, lista_atomica)
normal_modes_hs = df

# %% [markdown]
# # Plot contribuição do octaedro por modo normal

# %%
plt.plot(hs['index'],hs['array'],marker='o',label='High Spin',color='black')
plt.plot(ls['index'],ls['array'],marker='o',label='Low Spin',color='red')

plt.xlabel('Modo Normal')
plt.ylabel('Contribuição Octaedro')
plt.legend()
plt.show()

# %% [markdown]
# # Produto interno entre modos normais LS e HS.

# %%
valores_modos_hs = pd.read_csv('ls_tight/freq_modos.txt',header=None,sep='\s+')[1]
valores_modos_ls = pd.read_csv('hs_tight/freq_modos.txt',header=None,sep='\s+')[1]

# %%
# -------------------------
# 1) Monta a matriz (linhas = HS i, colunas = LS j)
# -------------------------
ini = 0
#ini = 6
lista_array_fin = []
for i in range(ini,159):
    iesimo_hs_nm = normal_modes_hs[str(i)]   # HS
    row = []
    for j in range(ini,159):
        jesimo_ls_nm = normal_modes_ls[str(j)]  # LS
        prod_intern_all = (iesimo_hs_nm * jesimo_ls_nm).sum()
        #row.append(abs(prod_intern_all))
        row.append((prod_intern_all))
    lista_array_fin.append(row)

prod_intern_all = pd.DataFrame(lista_array_fin)   # shape (HS, LS)
mat_all = prod_intern_all.to_numpy()
nrows_all, ncols_all = mat_all.shape

# %%
# -------------------------
# 2) Lê frequências corretamente (LS e HS)
#    (garante acesso posicional e tamanho compatível)
# -------------------------
valores_modos_ls = pd.read_csv(
    "ls/v2/freq_modos.txt", header=None, sep=r"\s+"
)[1].to_numpy()[ini:]

valores_modos_hs = pd.read_csv(
    "hs/freq_modos.txt", header=None, sep=r"\s+"
)[1].to_numpy()[ini:]

if len(valores_modos_ls) != ncols_all:
    raise ValueError(f"LS: esperado {ncols_all} frequências (colunas), veio {len(valores_modos_ls)}")

if len(valores_modos_hs) != nrows_all:
    raise ValueError(f"HS: esperado {nrows_all} frequências (linhas), veio {len(valores_modos_hs)}")

# %%
# -------------------------
# 3) Plota o mapa
# -------------------------
# for row in range(mat_all.shape[0]):      # HS
#     for col in range(mat_all.shape[1]):  # LS
#         hs_freq = float(valores_modos_hs[row])
#         ls_freq = float(valores_modos_ls[col])
#         if hs_freq > ls_freq:
#             mat_all[row, col] = 0.0

fig, ax = plt.subplots(figsize=(15, 15))
img = ax.imshow(
    mat_all,
    interpolation="nearest",
    origin="upper",
    aspect='equal',
    #vmin=0,
    #vmax=1
)
cbar = plt.colorbar(img, ax=ax)
cbar.set_label("Overlap Intensity", fontsize=20,labelpad=15)
cbar.ax.tick_params(labelsize=15)
#plt.colorbar(img, ax=ax)

#ax.set_title("Mapa de Calor do Produto Interno")
ax.set_xlabel("j-th Low Spin Normal Mode",fontsize=20)
ax.set_ylabel("i-th High Spin Normal Mode",fontsize=20)
ax.tick_params(axis='both', labelsize=15)

# -------------------------
# 4) Cursor interativo:
#    Para imshow/AxesImage use sel.index = (row, col)
# -------------------------
cursor = mplcursors.cursor(img, hover=True)

@cursor.connect("add")
def on_add(sel):
    row, col = sel.index  # row -> HS, col -> LS

    overlap_all = mat_all[row, col]
    ls_freq = float(valores_modos_ls[col])
    hs_freq = float(valores_modos_hs[row])
    
    sel.annotation.set_text(
        f"LS_freq = {ls_freq:.3f}  (col={col})\n"
        f"HS_freq = {hs_freq:.3f}  (row={row})\n"
        f"Overlap = {overlap_all:.4e}"
    )

plt.show()
#plt.savefig("fig.png")

# %%
mat_all
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -9.71047642e-01,  3.18019324e-04, -4.74295396e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.36211764e-04, -9.79167384e-01, -1.44035280e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          5.15639862e-04,  1.44081755e-01, -9.79095719e-01]],
#       shape=(159, 159))

# %%
A = np.array([
    [0.05, 0.3],
    [-0.08, 1.2]
])

A[np.abs(A) < 0.1] = 0

# %%
A
# Out:
# array([[0. , 0.3],
#        [0. , 1.2]])

# %%
import numpy as np

def svd_manual_block(mat_all, hs_modes, ls_modes):
    """
    mat_all[HS, LS] = overlap com sinal

    hs_modes e ls_modes são índices Python (ex: 91, 92)
    """

    hs_idx = hs_modes
    ls_idx = ls_modes

    # Agora linha = HS e coluna = LS
    block = mat_all[np.ix_(hs_idx, ls_idx)]

    U, S, Vt = np.linalg.svd(block)

    print("Bloco analisado (HS x LS):")
    print(block)

    print("\nValores singulares:")
    for k, sigma in enumerate(S, start=1):
        print(f"sigma_{k} = {sigma:.5f}")

    print("\nInterpretação do match:")
    for hs_mode in hs_modes:
        print(
            f"O modo normal HS {hs_mode} é uma combinação linear "
            f"dos modos normais LS {', '.join(map(str, ls_modes))}."
        )

    print("\nPesos individuais |overlap|²:")

    for h_mode, h_idx in zip(hs_modes, hs_idx):
        weights = np.abs(mat_all[h_idx, ls_idx])**2
        total = np.sum(weights)

        print(f"\nHS {h_mode}:")
        for l_mode, w in zip(ls_modes, weights):
            print(f"  contribuição de LS {l_mode}: {w:.4f}")
        print(f"  soma no subespaço LS = {total:.4f}")

# %%
svd_manual_block(
    mat_all,
    hs_modes=[135,136,137,138,139,140,141,142,143,144,145],
    ls_modes=[135,136,137,138,139,140,141,142,143,144,145]
)
# Out:
# Bloco analisado (HS x LS):
# [[ 1.97334303e-04  5.63008209e-01 -3.49882690e-01  6.11459309e-01
#   -2.94603881e-01  2.21597130e-04 -8.80846376e-02 -3.99279694e-04
#    9.47663569e-03 -1.21265980e-02 -4.30284446e-03]
#  [ 3.78182161e-01 -2.75179508e-03 -6.95111641e-01 -3.65702163e-01
#   -1.16241554e-03 -1.99277148e-01  6.62572127e-04  1.83773151e-01
#   -2.56505096e-02 -1.99107235e-02  1.02998975e-03]
#  [-4.12261133e-03 -4.41858326e-01 -2.76852550e-01  4.84574381e-01
#   -6.53609783e-01  7.87107745e-04  4.61041389e-01 -1.52969239e-03
#   -4.02983335e-02  5.21707195e-02 -1.06186217e-01]
#  [-4.63464047e-01  2.19655328e-03 -3.46714539e-01 -1.86143562e-01
#   -1.66995025e-04 -8.30465267e-01  1.04886251e-03 -2.66436673e-01
#    4.30176375e-02  3.32896875e-02  4.51416043e-02]
#  [ 9.82814929e-04  9.09931325e-02  1.14869050e-01 -2.01359536e-01
#    1.05972698e-02  2.54323502e-03  9.38189465e-01 -1.13962563e-03
#    3.91513941e-02 -5.04360822e-02 -9.28160432e-02]
#  [ 3.14918055e-01 -8.48562395e-04  2.82409226e-01  1.50390825e-01
#    1.68991501e-04 -3.02202840e-01 -7.38274059e-05 -8.46232678e-01
#   -7.59930719e-02 -5.89762948e-02  2.94562642e-02]
#  [-6.16441968e-01  1.43914434e-03 -2.86280960e-01 -1.52051425e-01
#    2.28914429e-03  4.36451976e-01 -1.47122605e-03 -4.91559807e-01
#    1.64117812e-01  1.27840934e-01  7.81646200e-03]
#  [-2.37484207e-03 -5.46933939e-01 -2.37829278e-01  4.18693629e-01
#    6.68251996e-01 -1.66867898e-03  1.09925141e-01  1.33291036e-03
#   -1.33011216e-01  1.70765539e-01 -8.78762392e-03]
#  [-8.86741144e-03  7.48743582e-02  1.94529494e-02 -3.96365349e-02
#   -7.36543140e-02  8.27546085e-03  4.26184829e-02  4.04041753e-04
#    6.66123451e-01 -7.01570222e-01  1.06341441e-02]
#  [-9.24389789e-02 -6.98796373e-03 -2.51628816e-02 -8.68373572e-03
#    7.42212513e-03  8.01457486e-02 -4.45489247e-03  5.46769639e-03
#    7.01747783e-01  6.65933843e-01  3.86012295e-03]
#  [-7.53896867e-02  1.30518835e-03 -2.78664256e-02 -1.57317658e-02
#   -4.12159428e-04  2.82385647e-02  1.82994706e-04  1.16881220e-02
#    7.72292273e-03  6.01296268e-03 -2.61957432e-01]]
#
# Valores singulares:
# sigma_1 = 1.18891
# sigma_2 = 1.17416
# sigma_3 = 1.17226
# sigma_4 = 1.13770
# sigma_5 = 1.08612
# sigma_6 = 1.06711
# sigma_7 = 0.81667
# sigma_8 = 0.79856
# sigma_9 = 0.65086
# sigma_10 = 0.64539
# sigma_11 = 0.25794
#
# Interpretação do match:
# O modo normal HS 135 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 136 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 137 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 138 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 139 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 140 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 141 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 142 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 143 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 144 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
# O modo normal HS 145 é uma combinação linear dos modos normais LS 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145.
#
# Pesos individuais |overlap|²:
#
# HS 135:
#   contribuição de LS 135: 0.0000
#   contribuição de LS 136: 0.3170
#   contribuição de LS 137: 0.1224
#   contribuição de LS 138: 0.3739
#   contribuição de LS 139: 0.0868
#   contribuição de LS 140: 0.0000
#   contribuição de LS 141: 0.0078
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.0001
#   contribuição de LS 144: 0.0001
#   contribuição de LS 145: 0.0000
#   soma no subespaço LS = 0.9081
#
# HS 136:
#   contribuição de LS 135: 0.1430
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.4832
#   contribuição de LS 138: 0.1337
#   contribuição de LS 139: 0.0000
#   contribuição de LS 140: 0.0397
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.0338
#   contribuição de LS 143: 0.0007
#   contribuição de LS 144: 0.0004
#   contribuição de LS 145: 0.0000
#   soma no subespaço LS = 0.8345
#
# HS 137:
#   contribuição de LS 135: 0.0000
#   contribuição de LS 136: 0.1952
#   contribuição de LS 137: 0.0766
#   contribuição de LS 138: 0.2348
#   contribuição de LS 139: 0.4272
#   contribuição de LS 140: 0.0000
#   contribuição de LS 141: 0.2126
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.0016
#   contribuição de LS 144: 0.0027
#   contribuição de LS 145: 0.0113
#   soma no subespaço LS = 1.1621
#
# HS 138:
#   contribuição de LS 135: 0.2148
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.1202
#   contribuição de LS 138: 0.0346
#   contribuição de LS 139: 0.0000
#   contribuição de LS 140: 0.6897
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.0710
#   contribuição de LS 143: 0.0019
#   contribuição de LS 144: 0.0011
#   contribuição de LS 145: 0.0020
#   soma no subespaço LS = 1.1353
#
# HS 139:
#   contribuição de LS 135: 0.0000
#   contribuição de LS 136: 0.0083
#   contribuição de LS 137: 0.0132
#   contribuição de LS 138: 0.0405
#   contribuição de LS 139: 0.0001
#   contribuição de LS 140: 0.0000
#   contribuição de LS 141: 0.8802
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.0015
#   contribuição de LS 144: 0.0025
#   contribuição de LS 145: 0.0086
#   soma no subespaço LS = 0.9550
#
# HS 140:
#   contribuição de LS 135: 0.0992
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.0798
#   contribuição de LS 138: 0.0226
#   contribuição de LS 139: 0.0000
#   contribuição de LS 140: 0.0913
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.7161
#   contribuição de LS 143: 0.0058
#   contribuição de LS 144: 0.0035
#   contribuição de LS 145: 0.0009
#   soma no subespaço LS = 1.0191
#
# HS 141:
#   contribuição de LS 135: 0.3800
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.0820
#   contribuição de LS 138: 0.0231
#   contribuição de LS 139: 0.0000
#   contribuição de LS 140: 0.1905
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.2416
#   contribuição de LS 143: 0.0269
#   contribuição de LS 144: 0.0163
#   contribuição de LS 145: 0.0001
#   soma no subespaço LS = 0.9605
#
# HS 142:
#   contribuição de LS 135: 0.0000
#   contribuição de LS 136: 0.2991
#   contribuição de LS 137: 0.0566
#   contribuição de LS 138: 0.1753
#   contribuição de LS 139: 0.4466
#   contribuição de LS 140: 0.0000
#   contribuição de LS 141: 0.0121
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.0177
#   contribuição de LS 144: 0.0292
#   contribuição de LS 145: 0.0001
#   soma no subespaço LS = 1.0366
#
# HS 143:
#   contribuição de LS 135: 0.0001
#   contribuição de LS 136: 0.0056
#   contribuição de LS 137: 0.0004
#   contribuição de LS 138: 0.0016
#   contribuição de LS 139: 0.0054
#   contribuição de LS 140: 0.0001
#   contribuição de LS 141: 0.0018
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.4437
#   contribuição de LS 144: 0.4922
#   contribuição de LS 145: 0.0001
#   soma no subespaço LS = 0.9510
#
# HS 144:
#   contribuição de LS 135: 0.0085
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.0006
#   contribuição de LS 138: 0.0001
#   contribuição de LS 139: 0.0001
#   contribuição de LS 140: 0.0064
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.0000
#   contribuição de LS 143: 0.4924
#   contribuição de LS 144: 0.4435
#   contribuição de LS 145: 0.0000
#   soma no subespaço LS = 0.9518
#
# HS 145:
#   contribuição de LS 135: 0.0057
#   contribuição de LS 136: 0.0000
#   contribuição de LS 137: 0.0008
#   contribuição de LS 138: 0.0002
#   contribuição de LS 139: 0.0000
#   contribuição de LS 140: 0.0008
#   contribuição de LS 141: 0.0000
#   contribuição de LS 142: 0.0001
#   contribuição de LS 143: 0.0001
#   contribuição de LS 144: 0.0000
#   contribuição de LS 145: 0.0686
#   soma no subespaço LS = 0.0764

# %% [markdown]
# # Produto interno entre modos normais LS e HS só do octaedro

# %%
normal_modes_hs_oct = normal_modes_hs.loc[['O1','O2','N3','N4','N5','N6','Fe1']]
normal_modes_ls_oct = normal_modes_ls.loc[['O1','O2','N3','N4','N5','N6','Fe1']]

lista_array_ini = []
lista_array_fin = []

for i in range(0,159):
    iesimo_hs_nm = normal_modes_hs_oct[str(i)]
    for j in range(0,159):
        jesimo_ls_nm = normal_modes_ls_oct[str(j)]
        prod_intern_oct = abs((iesimo_hs_nm*jesimo_ls_nm).sum())
        lista_array_ini.append(abs(prod_intern_oct))
    lista_array_fin.append(lista_array_ini)
    lista_array_ini = []   

prod_intern_oct = pd.DataFrame(lista_array_fin)

# %%
mat_oct = prod_intern_oct.values
nrows_oct, ncols_oct = mat_oct.shape

fig, ax = plt.subplots(figsize=(15, 15))

img = ax.imshow(mat_oct, interpolation='nearest', origin='upper')
#plt.colorbar(img, label='Intensidade')
plt.colorbar(img, label='Intensidade')

#ax.set_title('Mapa de Calor do Produto Interno do Octaedro')
ax.set_xlabel('Low Spin')
ax.set_ylabel('High Spin')

cursor = mplcursors.cursor(img, hover=True)

@cursor.connect("add")
def on_add(sel):
    row, col = sel.index  # row -> HS, col -> LS

    overlap_oct = mat_oct[row, col]
    ls_freq = float(valores_modos_ls[col])
    hs_freq = float(valores_modos_hs[row])

    sel.annotation.set_text(
        f"LS_freq = {ls_freq:.3f}  (col={col})\n"
        f"HS_freq = {hs_freq:.3f}  (row={row})\n"
        f"Overlap = {overlap_oct:.4e}"
    )

plt.show()

# %% [markdown]
# # Produto interno entre modos normais LS e HS da molecula inteira sem contar o octaedro

# %%
remover = ['O1','O2','N3','N4','N5','N6','Fe1']
resultado = [i for i in normal_modes_hs.index.unique() if i not in remover]

normal_modes_hs_mol = normal_modes_hs.loc[resultado]
normal_modes_ls_mol = normal_modes_ls.loc[resultado]

lista_array_ini = []
lista_array_fin = []

for i in range(0,159):
    iesimo_hs_nm = normal_modes_hs_mol[str(i)]
    for j in range(0,159):
        jesimo_ls_nm = normal_modes_ls_mol[str(j)]
        prod_intern_mol = abs((iesimo_hs_nm*jesimo_ls_nm).sum())
        lista_array_ini.append(abs(prod_intern_mol))
    lista_array_fin.append(lista_array_ini)
    lista_array_ini = []   

prod_intern_mol = pd.DataFrame(lista_array_fin)

# %%
mat_mol = prod_intern_mol.values
nrows_mol, ncols_mol = mat_mol.shape

fig, ax = plt.subplots(figsize=(15, 15))

img = ax.imshow(mat_mol, interpolation='nearest', origin='upper')
plt.colorbar(img, label='Intensidade')

ax.set_title('Mapa de Calor do Produto Interno da Molecula')
ax.set_xlabel('Modo Normal LS')
ax.set_ylabel('Modo Normal HS')

cursor = mplcursors.cursor(img, hover=True)

@cursor.connect("add")
def on_add(sel):
    row, col = sel.index  # row -> HS, col -> LS

    overlap_mol = mat_mol[row, col]
    ls_freq = float(valores_modos_ls[col])
    hs_freq = float(valores_modos_hs[row])

    sel.annotation.set_text(
        f"LS_freq = {ls_freq:.3f}  (col={col})\n"
        f"HS_freq = {hs_freq:.3f}  (row={row})\n"
        f"Overlap = {overlap_mol:.4e}"
    )

plt.show()

# %% [markdown]
# # Teste do produto interno ponderado pela massa (Molecula inteira)

# %%
valores_modos_hs = pd.read_csv('ls/v2/freq_modos.txt',header=None,sep='\s+')[1]
valores_modos_ls = pd.read_csv('hs/freq_modos.txt',header=None,sep='\s+')[1]

# %%
# -------------------------
# 1) Monta a matriz (linhas = HS i, colunas = LS j)
# -------------------------
for i in range(159):
    iesimo_hs_nm= normal_modes_hs[str(i)]   # HS

elements = iesimo_hs_nm.index.to_series().str.extract(r'([A-Za-z]+)')[0]

mass_dict = {
    'H': 1.008,
    'C': 12.011,
    'N': 14.007,
    'O': 15.999,
    'Fe': 55.845
}

masses = elements.map(mass_dict)

# -------------------------
# 1.2) Monta a matriz ponderada pela massa(linhas = HS i, colunas = LS j)
# -------------------------

lista_array_fin = []
for i in range(159):
    iesimo_hs_nm = normal_modes_hs[str(i)]*masses  # HS
    row = []
    for j in range(159):
        jesimo_ls_nm = normal_modes_ls[str(j)]*masses  # LS
        prod_intern_all_norm = ((iesimo_hs_nm * jesimo_ls_nm).sum())/(masses.sum())
        row.append(abs(prod_intern_all_norm))
    lista_array_fin.append(row)

prod_intern_all_norm = pd.DataFrame(lista_array_fin)   # shape (HS, LS)
mat_all_norm = prod_intern_all_norm.to_numpy()
nrows_all_norm, ncols_all_norm = mat_all_norm.shape

# %%
# -------------------------
# 2) Plota o mapa
# -------------------------
fig, ax = plt.subplots(figsize=(15, 15))
img = ax.imshow(mat_all_norm, interpolation="nearest", origin="upper", aspect = 'equal')
plt.colorbar(img, ax=ax, label="Intensidade")

ax.set_title("Mapa de Calor do Produto Interno")
ax.set_xlabel("Modo Normal LS (coluna)")
ax.set_ylabel("Modo Normal HS (linha)")

# -------------------------
# 3) Cursor interativo:
#    Para imshow/AxesImage use sel.index = (row, col)
# -------------------------
cursor = mplcursors.cursor(img, hover=True)

@cursor.connect("add")
def on_add(sel):
    row, col = sel.index  # row -> HS, col -> LS

    overlap_all_norm = mat_all_norm[row, col]
    ls_freq = float(valores_modos_ls[col])
    hs_freq = float(valores_modos_hs[row])

    sel.annotation.set_text(
        f"LS_freq = {ls_freq:.3f}  (col={col})\n"
        f"HS_freq = {hs_freq:.3f}  (row={row})\n"
        f"Overlap = {overlap_all_norm:.4e}"
    )

plt.show()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\backends\backend_qt.py", line 523, in _draw_idle
#     self.draw()
#     ~~~~~~~~~^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py", line 382, in draw
#     self.figure.draw(self.renderer)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\artist.py", line 94, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\figure.py", line 3257, in draw
#     mimage._draw_list_compositing_images(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         renderer, self, artists, self.suppressComposite)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\image.py", line 134, in _draw_list_compositing_images
#     a.draw(renderer)
#     ~~~~~~^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\text.py", line 2000, in draw
#     self.arrow_patch.draw(renderer)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\artist.py", line 38, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\patches.py", line 4503, in draw
#     path, fillable = self._get_path_in_displaycoord()
#                      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\patches.py", line 4478, in _get_path_in_displaycoord
#     _path = self.get_connectionstyle()(posA, posB,
#                                        patchA=self.patchA,
#     ...<2 lines>...
#                                        shrinkB=self.shrinkB * dpi_cor
#                                        )
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\patches.py", line 2832, in __call__
#     path = self._clip(
#         path,
#         self._in_patch(patchA) if patchA else None,
#         self._in_patch(patchB) if patchB else None,
#     )
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\patches.py", line 2815, in _clip
#     _, path = split_path_inout(path, in_start)
#               ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\bezier.py", line 359, in split_path_inout
#     ctl_points, command = next(path_iter)
#                           ~~~~^^^^^^^^^^^
# StopIteration
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
# Traceback (most recent call last):
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 579, in _on_hover_motion_notify
#     self._on_select_event(event)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 627, in _on_select_event
#     return self.add_selection(*candidates_nodupe[0])
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\alanf\anaconda3\Lib\site-packages\mplcursors\_mplcursors.py", line 390, in add_selection
#     cb(sel)
#     ~~^^^^^
#   File "C:\Users\alanf\AppData\Local\Temp\ipykernel_2736\3481600967.py", line 29, in on_add
#     f"Overlap = {overlap_all_norm:.4e}"
#                  ^^^^^^^^^^^^^^^^
# NameError: name 'overlap_all_norm' is not defined. Did you mean: 'overlap_all'?
